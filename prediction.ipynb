# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow.keras.models import load_model

age = load_model('AGE_CNN')
gender = load_model('GENDER_CNN')

# %%
def age_in_year(label):
    age1 = ["[1-16]","[17-28]","[29-54]","[>54]"]
    return age1[int(label)]
def gender_of_person(label):
    gender1 = [ "Male" , "Female"]
    if label < 0.5:
      return gender1[0]
    else:
      return gender1[1]

# %%
def predict_img(path):
    colored = cv.imread(path)
    colored = cv.cvtColor(colored, cv.COLOR_BGR2RGB )
    image = cv.imread(path,0)
    image = cv.resize(image,(128,128))
    image = np.array(image)
    a = age_in_year(np.argmax(age.predict(np.expand_dims(image, 0))))
    g = gender_of_person(gender.predict(np.expand_dims(image, 0)))
    plt.title(f'predict:{a} {g}')
    plt.imshow(colored)
    plt.axis("off")

# %%
path = 'mona.jpg'
predict_img(path)
# Out:
# ...
# 1/1 [==============================] - 0s 204ms/step

# %%
path = 'sel.jpg'
predict_img(path)
# Out:
# ...
# 1/1 [==============================] - 0s 48ms/step

# %%
path = 'taim.jpg'
predict_img(path)
# Out:
# ...
# 1/1 [==============================] - 0s 37ms/step

# %%
path = 'img.jpeg'
predict_img(path)
# Out:
# ...
# 1/1 [==============================] - 0s 40ms/step

# %%
path = 'baby.jpg'
predict_img(path)
# Out:
# ...
# 1/1 [==============================] - 0s 38ms/step
